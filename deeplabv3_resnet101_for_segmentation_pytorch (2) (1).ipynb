# %% [markdown]
# ## Introduction
#
# ### In this notebook we use [DeepLabV3+](https://arxiv.org/abs/1802.02611) segmentation model for performing building segmentation on [Massachusetts Buildings Dataset](https://www.cs.toronto.edu/~vmnih/docs/Mnih_Volodymyr_PhD_Thesis.pdf).

# %% [markdown]
# ### Libraries 📚⬇

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -U segmentation-models-pytorch albumentations > /dev/null
import segmentation_models_pytorch as smp

# %%
import os, cv2
import numpy as np
import pandas as pd
import random, tqdm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import albumentations as album
print("done")
# Out:
# done

# %% [markdown]
# ### Defining train / val / test directories 📁

# %%
DATA_DIR =  '/content/drive/My Drive/M_DATA/tiff/'

x_train_dir = os.path.join(DATA_DIR, 'train')
y_train_dir = os.path.join(DATA_DIR, 'train_labels')

x_valid_dir = os.path.join(DATA_DIR, 'val')
y_valid_dir = os.path.join(DATA_DIR, 'val_labels')

x_test_dir = os.path.join(DATA_DIR, 'test')
y_test_dir = os.path.join(DATA_DIR, 'test_labels')

# %%
class_dict = pd.read_csv("/content/drive/My Drive/M_DATA/label_class_dict.csv")
# Get class names
class_names = class_dict['name'].tolist()
# Get class RGB values
class_rgb_values = class_dict[['r','g','b']].values.tolist()

print('All dataset classes and their corresponding RGB values in labels:')
print('Class Names: ', class_names)
print('Class RGB values: ', class_rgb_values)
# Out:
# All dataset classes and their corresponding RGB values in labels:
# Class Names:  ['background', 'building']
# Class RGB values:  [[0, 0, 0], [255, 255, 255]]

# %% [markdown]
# #### Shortlist specific classes to segment

# %%
# Useful to shortlist specific classes in datasets with large number of classes
select_classes = ['background', 'building']

# Get RGB values of required classes
select_class_indices = [class_names.index(cls.lower()) for cls in select_classes]
select_class_rgb_values =  np.array(class_rgb_values)[select_class_indices]

print('Selected classes and their corresponding RGB values in labels:')
print('Class Names: ', class_names)
print('Class RGB values: ', class_rgb_values)
# Out:
# Selected classes and their corresponding RGB values in labels:
# Class Names:  ['background', 'building']
# Class RGB values:  [[0, 0, 0], [255, 255, 255]]

# %% [markdown]
# ### Helper functions for viz. & one-hot encoding/decoding

# %%
# helper function for data visualization
def visualize(**images):
    """
    Plot images in one row
    """
    n_images = len(images)
    plt.figure(figsize=(20,8))
    for idx, (name, image) in enumerate(images.items()):
        plt.subplot(1, n_images, idx + 1)
        plt.xticks([]);
        plt.yticks([])
        # get title from the parameter names
        plt.title(name.replace('_',' ').title(), fontsize=20)
        plt.imshow(image)
    plt.show()

# Perform one hot encoding on label
def one_hot_encode(label, label_values):
    """
    Convert a segmentation image label array to one-hot format
    by replacing each pixel value with a vector of length num_classes
    # Arguments
        label: The 2D array segmentation image label
        label_values

    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of num_classes
    """
    semantic_map = []
    for colour in label_values:
        equality = np.equal(label, colour)
        class_map = np.all(equality, axis = -1)
        semantic_map.append(class_map)
    semantic_map = np.stack(semantic_map, axis=-1)

    return semantic_map

# Perform reverse one-hot-encoding on labels / preds
def reverse_one_hot(image):
    """
    Transform a 2D array in one-hot format (depth is num_classes),
    to a 2D array with only 1 channel, where each pixel value is
    the classified class key.
    # Arguments
        image: The one-hot format image

    # Returns
        A 2D array with the same width and hieght as the input, but
        with a depth size of 1, where each pixel value is the classified
        class key.
    """
    x = np.argmax(image, axis = -1)
    return x

# Perform colour coding on the reverse-one-hot outputs
def colour_code_segmentation(image, label_values):
    """
    Given a 1-channel array of class keys, colour code the segmentation results.
    # Arguments
        image: single channel array where each value represents the class key.
        label_values

    # Returns
        Colour coded image for segmentation visualization
    """
    colour_codes = np.array(label_values)
    x = colour_codes[image.astype(int)]

    return x

# %%
class BuildingsDataset(torch.utils.data.Dataset):

    """Massachusetts Buildings Dataset. Read images, apply augmentation and preprocessing transformations.

    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_rgb_values (list): RGB values of select classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing
            (e.g. noralization, shape manipulation, etc.)

    """

    def __init__(
            self,
            images_dir,
            masks_dir,
            class_rgb_values=None,
            augmentation=None,
            preprocessing=None,
    ):

        self.image_paths = [os.path.join(images_dir, image_id) for image_id in sorted(os.listdir(images_dir))]
        self.mask_paths = [os.path.join(masks_dir, image_id) for image_id in sorted(os.listdir(masks_dir))]

        self.class_rgb_values = class_rgb_values
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):

        # read images and masks
        image = cv2.cvtColor(cv2.imread(self.image_paths[i]), cv2.COLOR_BGR2RGB)
        mask = cv2.cvtColor(cv2.imread(self.mask_paths[i]), cv2.COLOR_BGR2RGB)

        # one-hot-encode the mask
        mask = one_hot_encode(mask, self.class_rgb_values).astype('float')

        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']

        return image, mask

    def __len__(self):
        # return length of
        return len(self.image_paths)

# %% [markdown]
# #### Visualize Sample Image and Mask 📈

# %%
dataset = BuildingsDataset(x_train_dir, y_train_dir, class_rgb_values=select_class_rgb_values)
random_idx = random.randint(0, len(dataset)-1)
image, mask = dataset[2]

visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask)
)

# %% [markdown]
# ### Defining Augmentations 🙃

# %%
def get_training_augmentation():
    train_transform = [
        album.RandomCrop(height=256, width=256, always_apply=True),
        album.OneOf(
            [
                album.HorizontalFlip(p=1),
                album.VerticalFlip(p=1),
                album.RandomRotate90(p=1),
            ],
            p=0.75,
        ),
    ]
    return album.Compose(train_transform)


def get_validation_augmentation():
    # Add sufficient padding to ensure image is divisible by 32
    test_transform = [
        album.PadIfNeeded(min_height=1536, min_width=1536, always_apply=True, border_mode=0,value=0),
    ]
    return album.Compose(test_transform)


def to_tensor(x, **kwargs):
    return x.transpose(2, 0, 1).astype('float32')


def get_preprocessing(preprocessing_fn=None):
    """Construct preprocessing transform
    Args:
        preprocessing_fn (callable): data normalization function
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    """
    _transform = []
    if preprocessing_fn:
        _transform.append(album.Lambda(image=preprocessing_fn))
    _transform.append(album.Lambda(image=to_tensor, mask=to_tensor))

    return album.Compose(_transform)

# %% [markdown]
# #### Visualize Augmented Images & Masks

# %%
augmented_dataset = BuildingsDataset(
    x_train_dir, y_train_dir,
    augmentation=get_training_augmentation(),
    class_rgb_values=select_class_rgb_values,
)

random_idx = random.randint(0, len(augmented_dataset)-1)

# Different augmentations on a random image/mask pair (256*256 crop)
for i in range(3):
    image, mask = augmented_dataset[random_idx]
    visualize(
        original_image = image,
        ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
        one_hot_encoded_mask = reverse_one_hot(mask)
    )

# %% [markdown]
# ## Training DeepLabV3+ with Pretrained ResNet101 Encoder

# %% [markdown]
# <h3><center>DeepLabV3+ Model Architecture</center></h3>
# <img src="https://miro.medium.com/max/1037/1*2mYfKnsX1IqCCSItxpXSGA.png" width="750" height="750"/>
# <h4><center><a href="https://arxiv.org/abs/1802.02611">Image Courtesy: DeepLabV3+ [Chen et al.]</a></center></h4>

# %% [markdown]
# ### Model Definition

# %%
ENCODER = 'resnet101'
ENCODER_WEIGHTS = 'imagenet'
CLASSES = class_names
ACTIVATION = 'sigmoid' # could be None for logits or 'softmax2d' for multiclass segmentation

# create segmentation model with pretrained encoder
model = smp.DeepLabV3Plus(
    encoder_name=ENCODER,
    encoder_weights=ENCODER_WEIGHTS,
    classes=len(CLASSES),
    activation=ACTIVATION,
)

preprocessing_fn = smp.encoders.get_preprocessing_fn(ENCODER, ENCODER_WEIGHTS)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100%|██████████| 170M/170M [00:02<00:00, 82.0MB/s]

# %% [markdown]
# #### Get Train / Val DataLoaders

# %%
# Get train and val dataset instances
train_dataset = BuildingsDataset(
    x_train_dir, y_train_dir,
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=select_class_rgb_values,
)

valid_dataset = BuildingsDataset(
    x_valid_dir, y_valid_dir,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=select_class_rgb_values,
)

# Get train and val data loaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=5)
valid_loader = DataLoader(valid_dataset, batch_size=1, shuffle=False, num_workers=2)

# %% [markdown]
# #### Set Hyperparams

# %%
# Set flag to train the model or not. If set to 'False', only prediction is performed (using an older model checkpoint)
import segmentation_models_pytorch as smp
import segmentation_models_pytorch.utils  # Import losses separately
# import segmentation_models_pytorch.metrics as smp_metrics
TRAINING = True

# Set num of epochs
EPOCHS = 200

# Set device: `cuda` or `cpu`
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# define loss function
loss = smp.utils.losses.DiceLoss()

# define metrics
metrics = [
    smp.utils.metrics.IoU(threshold=0.5),
]

# define optimizer
optimizer = torch.optim.Adam([
    dict(params=model.parameters(), lr=0.0001),
])

# define learning rate scheduler (not used in this NB)
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer, T_0=1, T_mult=2, eta_min=5e-5,
)

# # load best saved model checkpoint from previous commit (if present)
# if os.path.exists('../input/deeplabv3-efficientnetb4-frontend-using-pytorch/best_model.pth'):
#     model = torch.load('../input/deeplabv3-efficientnetb4-frontend-using-pytorch/best_model.pth', map_location=DEVICE)

# %%
# Path to the model file in the current environment
local_model_path = '/content/best_model.pth'

# Path to the model file in Google Drive
drive_model_path = '/content/drive/MyDrive/M_DATA/Check_point/best_model.pth'

# Check if the model file exists
if os.path.exists(local_model_path):
    # Load the model
    model = torch.load(local_model_path, map_location=DEVICE)

    # Ensure the destination directory exists
    os.makedirs(os.path.dirname(drive_model_path), exist_ok=True)

    # Save the model to Google Drive
    torch.save(model, drive_model_path)
    print(f'Model saved to {drive_model_path}')
else:
    print(f'Model file does not exist at {local_model_path}')
# Out:
# Model file does not exist at /content/best_model.pth

# %%
train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss=loss,
    metrics=metrics,
    optimizer=optimizer,
    device=DEVICE,
    verbose=True,
)

valid_epoch = smp.utils.train.ValidEpoch(
    model,
    loss=loss,
    metrics=metrics,
    device=DEVICE,
    verbose=True,
)

# %% [markdown]
# ### Training DeepLabV3+

# %%
# %%time

if TRAINING:

    best_iou_score = 0.0
    train_logs_list, valid_logs_list = [], []

    for i in range(0, EPOCHS):

        # Perform training & validation
        print('\nEpoch: {}'.format(i))
        train_logs = train_epoch.run(train_loader)
        valid_logs = valid_epoch.run(valid_loader)
        train_logs_list.append(train_logs)
        valid_logs_list.append(valid_logs)

        # Save model if a better val IoU score is obtained
        if best_iou_score < valid_logs['iou_score']:
            best_iou_score = valid_logs['iou_score']
            torch.save(model, '/content/best_model.pth')
            torch.save(model, '/content/drive/MyDrive/M_DATA/Check_point/best_model.pth')

            print('Model saved!')
# Out:
# Epoch: 0
# train: 100%|██████████| 9/9 [00:41<00:00,  4.63s/it, dice_loss - 0.5055, iou_score - 0.3316]
# valid: 100%|██████████| 4/4 [00:09<00:00,  2.28s/it, dice_loss - 0.5188, iou_score - 0.2562]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 9/9 [00:43<00:00,  4.86s/it, dice_loss - 0.4325, iou_score - 0.561]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.95s/it, dice_loss - 0.5706, iou_score - 0.4504]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 9/9 [00:43<00:00,  4.85s/it, dice_loss - 0.3839, iou_score - 0.6235]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.95s/it, dice_loss - 0.446, iou_score - 0.674]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 9/9 [00:45<00:00,  5.00s/it, dice_loss - 0.3522, iou_score - 0.6547]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.74s/it, dice_loss - 0.3866, iou_score - 0.7253]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 9/9 [00:44<00:00,  4.98s/it, dice_loss - 0.3358, iou_score - 0.6546]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.93s/it, dice_loss - 0.3309, iou_score - 0.7329]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 9/9 [00:42<00:00,  4.73s/it, dice_loss - 0.3008, iou_score - 0.6929]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.09s/it, dice_loss - 0.2923, iou_score - 0.7489]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 9/9 [00:44<00:00,  4.90s/it, dice_loss - 0.2905, iou_score - 0.6995]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.67s/it, dice_loss - 0.2675, iou_score - 0.7601]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 9/9 [00:44<00:00,  4.98s/it, dice_loss - 0.269, iou_score - 0.7248]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.03s/it, dice_loss - 0.2863, iou_score - 0.7179]
#
# Epoch: 8
# train: 100%|██████████| 9/9 [00:41<00:00,  4.58s/it, dice_loss - 0.2547, iou_score - 0.7467]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.61s/it, dice_loss - 0.2855, iou_score - 0.72]
#
# Epoch: 9
# train: 100%|██████████| 9/9 [00:42<00:00,  4.68s/it, dice_loss - 0.2443, iou_score - 0.7637]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.08s/it, dice_loss - 0.2847, iou_score - 0.7226]
#
# Epoch: 10
# train: 100%|██████████| 9/9 [00:42<00:00,  4.70s/it, dice_loss - 0.238, iou_score - 0.7617]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.69s/it, dice_loss - 0.2767, iou_score - 0.722]
#
# Epoch: 11
# train: 100%|██████████| 9/9 [00:41<00:00,  4.62s/it, dice_loss - 0.2202, iou_score - 0.791]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.78s/it, dice_loss - 0.2582, iou_score - 0.7528]
#
# Epoch: 12
# train: 100%|██████████| 9/9 [00:42<00:00,  4.74s/it, dice_loss - 0.2186, iou_score - 0.775]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.99s/it, dice_loss - 0.2179, iou_score - 0.7837]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 9/9 [00:44<00:00,  5.00s/it, dice_loss - 0.2216, iou_score - 0.762]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.66s/it, dice_loss - 0.2071, iou_score - 0.7842]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 9/9 [00:44<00:00,  4.90s/it, dice_loss - 0.2037, iou_score - 0.7869]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.75s/it, dice_loss - 0.2482, iou_score - 0.7243]
#
# Epoch: 15
# train: 100%|██████████| 9/9 [00:42<00:00,  4.72s/it, dice_loss - 0.1958, iou_score - 0.7863]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.92s/it, dice_loss - 0.2119, iou_score - 0.7775]
#
# Epoch: 16
# train: 100%|██████████| 9/9 [00:41<00:00,  4.63s/it, dice_loss - 0.196, iou_score - 0.7783]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.85s/it, dice_loss - 0.2106, iou_score - 0.7723]
#
# Epoch: 17
# train: 100%|██████████| 9/9 [00:41<00:00,  4.63s/it, dice_loss - 0.193, iou_score - 0.7799]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.75s/it, dice_loss - 0.2026, iou_score - 0.7785]
#
# Epoch: 18
# train: 100%|██████████| 9/9 [00:41<00:00,  4.61s/it, dice_loss - 0.1833, iou_score - 0.7939]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.59s/it, dice_loss - 0.221, iou_score - 0.7535]
#
# Epoch: 19
# train: 100%|██████████| 9/9 [00:42<00:00,  4.68s/it, dice_loss - 0.1814, iou_score - 0.7917]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.67s/it, dice_loss - 0.2043, iou_score - 0.7672]
#
# Epoch: 20
# train: 100%|██████████| 9/9 [00:42<00:00,  4.69s/it, dice_loss - 0.1708, iou_score - 0.8034]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.77s/it, dice_loss - 0.1935, iou_score - 0.7773]
#
# Epoch: 21
# train: 100%|██████████| 9/9 [00:41<00:00,  4.66s/it, dice_loss - 0.174, iou_score - 0.79]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.05s/it, dice_loss - 0.1869, iou_score - 0.7889]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 9/9 [00:44<00:00,  4.99s/it, dice_loss - 0.1709, iou_score - 0.7922]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.84s/it, dice_loss - 0.1964, iou_score - 0.7735]
#
# Epoch: 23
# train: 100%|██████████| 9/9 [00:41<00:00,  4.64s/it, dice_loss - 0.1595, iou_score - 0.8087]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.98s/it, dice_loss - 0.189, iou_score - 0.7729]
#
# Epoch: 24
# train: 100%|██████████| 9/9 [00:42<00:00,  4.71s/it, dice_loss - 0.1606, iou_score - 0.8033]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.85s/it, dice_loss - 0.1764, iou_score - 0.7814]
#
# Epoch: 25
# train: 100%|██████████| 9/9 [00:41<00:00,  4.66s/it, dice_loss - 0.1565, iou_score - 0.8053]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.69s/it, dice_loss - 0.178, iou_score - 0.7849]
#
# Epoch: 26
# train: 100%|██████████| 9/9 [00:42<00:00,  4.73s/it, dice_loss - 0.1482, iou_score - 0.8197]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.98s/it, dice_loss - 0.1805, iou_score - 0.7838]
#
# Epoch: 27
# train: 100%|██████████| 9/9 [00:42<00:00,  4.69s/it, dice_loss - 0.1491, iou_score - 0.8127]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.66s/it, dice_loss - 0.1809, iou_score - 0.7794]
#
# Epoch: 28
# train: 100%|██████████| 9/9 [00:41<00:00,  4.65s/it, dice_loss - 0.1427, iou_score - 0.8208]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.17s/it, dice_loss - 0.1739, iou_score - 0.7907]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 9/9 [00:45<00:00,  5.02s/it, dice_loss - 0.1479, iou_score - 0.8086]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.94s/it, dice_loss - 0.1676, iou_score - 0.7957]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 9/9 [00:44<00:00,  4.96s/it, dice_loss - 0.1421, iou_score - 0.8145]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.06s/it, dice_loss - 0.1547, iou_score - 0.8095]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 9/9 [00:45<00:00,  5.03s/it, dice_loss - 0.1402, iou_score - 0.8203]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.71s/it, dice_loss - 0.1467, iou_score - 0.8195]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 9/9 [00:46<00:00,  5.11s/it, dice_loss - 0.1387, iou_score - 0.8208]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.83s/it, dice_loss - 0.1488, iou_score - 0.812]
#
# Epoch: 33
# train: 100%|██████████| 9/9 [00:42<00:00,  4.68s/it, dice_loss - 0.129, iou_score - 0.8371]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.89s/it, dice_loss - 0.1468, iou_score - 0.8141]
#
# Epoch: 34
# train: 100%|██████████| 9/9 [00:41<00:00,  4.65s/it, dice_loss - 0.1251, iou_score - 0.8411]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.14s/it, dice_loss - 0.1572, iou_score - 0.801]
#
# Epoch: 35
# train: 100%|██████████| 9/9 [00:42<00:00,  4.67s/it, dice_loss - 0.1291, iou_score - 0.8295]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.92s/it, dice_loss - 0.1636, iou_score - 0.7916]
#
# Epoch: 36
# train: 100%|██████████| 9/9 [00:42<00:00,  4.69s/it, dice_loss - 0.1199, iou_score - 0.8445]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.01s/it, dice_loss - 0.173, iou_score - 0.774]
#
# Epoch: 37
# train: 100%|██████████| 9/9 [00:42<00:00,  4.67s/it, dice_loss - 0.1241, iou_score - 0.8339]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.90s/it, dice_loss - 0.2085, iou_score - 0.7235]
#
# Epoch: 38
# train: 100%|██████████| 9/9 [00:42<00:00,  4.68s/it, dice_loss - 0.1264, iou_score - 0.8278]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.91s/it, dice_loss - 0.168, iou_score - 0.7776]
#
# Epoch: 39
# train: 100%|██████████| 9/9 [00:41<00:00,  4.64s/it, dice_loss - 0.1229, iou_score - 0.8327]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.01s/it, dice_loss - 0.1574, iou_score - 0.7916]
#
# Epoch: 40
# train: 100%|██████████| 9/9 [00:42<00:00,  4.75s/it, dice_loss - 0.122, iou_score - 0.8315]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.72s/it, dice_loss - 0.1324, iou_score - 0.8207]
# Model saved!
#
# Epoch: 41
# train: 100%|██████████| 9/9 [00:45<00:00,  5.10s/it, dice_loss - 0.1232, iou_score - 0.8277]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.15s/it, dice_loss - 0.1352, iou_score - 0.8185]
#
# Epoch: 42
# train: 100%|██████████| 9/9 [00:41<00:00,  4.64s/it, dice_loss - 0.1165, iou_score - 0.8361]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.08s/it, dice_loss - 0.1649, iou_score - 0.7763]
#
# Epoch: 43
# train: 100%|██████████| 9/9 [00:42<00:00,  4.67s/it, dice_loss - 0.1224, iou_score - 0.825]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.94s/it, dice_loss - 0.1251, iou_score - 0.8243]
# Model saved!
#
# Epoch: 44
# train: 100%|██████████| 9/9 [00:44<00:00,  4.91s/it, dice_loss - 0.1119, iou_score - 0.8418]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.16s/it, dice_loss - 0.1181, iou_score - 0.8345]
# Model saved!
#
# Epoch: 45
# train: 100%|██████████| 9/9 [00:45<00:00,  5.05s/it, dice_loss - 0.1138, iou_score - 0.8396]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.02s/it, dice_loss - 0.1372, iou_score - 0.8114]
#
# Epoch: 46
# train: 100%|██████████| 9/9 [00:42<00:00,  4.70s/it, dice_loss - 0.1084, iou_score - 0.8473]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.07s/it, dice_loss - 0.1373, iou_score - 0.8089]
#
# Epoch: 47
# train: 100%|██████████| 9/9 [00:41<00:00,  4.66s/it, dice_loss - 0.1094, iou_score - 0.8431]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.86s/it, dice_loss - 0.1193, iou_score - 0.8311]
#
# Epoch: 48
# train: 100%|██████████| 9/9 [00:42<00:00,  4.77s/it, dice_loss - 0.1063, iou_score - 0.8478]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.94s/it, dice_loss - 0.1217, iou_score - 0.834]
#
# Epoch: 49
# train: 100%|██████████| 9/9 [00:42<00:00,  4.77s/it, dice_loss - 0.1069, iou_score - 0.845]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.73s/it, dice_loss - 0.1242, iou_score - 0.829]
#
# Epoch: 50
# train: 100%|██████████| 9/9 [00:42<00:00,  4.72s/it, dice_loss - 0.1114, iou_score - 0.8366]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.16s/it, dice_loss - 0.1266, iou_score - 0.8227]
#
# Epoch: 51
# train: 100%|██████████| 9/9 [00:44<00:00,  4.89s/it, dice_loss - 0.1127, iou_score - 0.8324]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.07s/it, dice_loss - 0.1146, iou_score - 0.8343]
#
# Epoch: 52
# train: 100%|██████████| 9/9 [00:43<00:00,  4.83s/it, dice_loss - 0.1026, iou_score - 0.8491]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.20s/it, dice_loss - 0.1171, iou_score - 0.8321]
#
# Epoch: 53
# train: 100%|██████████| 9/9 [00:42<00:00,  4.71s/it, dice_loss - 0.1063, iou_score - 0.8427]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.08s/it, dice_loss - 0.1181, iou_score - 0.8289]
#
# Epoch: 54
# train: 100%|██████████| 9/9 [00:42<00:00,  4.70s/it, dice_loss - 0.1039, iou_score - 0.845]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.80s/it, dice_loss - 0.1152, iou_score - 0.8342]
#
# Epoch: 55
# train: 100%|██████████| 9/9 [00:41<00:00,  4.63s/it, dice_loss - 0.107, iou_score - 0.8402]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.82s/it, dice_loss - 0.1105, iou_score - 0.8384]
# Model saved!
#
# Epoch: 56
# train: 100%|██████████| 9/9 [00:44<00:00,  4.99s/it, dice_loss - 0.0988, iou_score - 0.8513]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.23s/it, dice_loss - 0.1112, iou_score - 0.8379]
#
# Epoch: 57
# train: 100%|██████████| 9/9 [00:42<00:00,  4.76s/it, dice_loss - 0.1038, iou_score - 0.8424]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.06s/it, dice_loss - 0.1169, iou_score - 0.8278]
#
# Epoch: 58
# train: 100%|██████████| 9/9 [00:41<00:00,  4.63s/it, dice_loss - 0.1051, iou_score - 0.8388]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.97s/it, dice_loss - 0.1169, iou_score - 0.8273]
#
# Epoch: 59
# train: 100%|██████████| 9/9 [00:43<00:00,  4.78s/it, dice_loss - 0.09931, iou_score - 0.8486]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.05s/it, dice_loss - 0.1082, iou_score - 0.8389]
# Model saved!
#
# Epoch: 60
# train: 100%|██████████| 9/9 [00:46<00:00,  5.15s/it, dice_loss - 0.09222, iou_score - 0.8603]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.94s/it, dice_loss - 0.1049, iou_score - 0.8413]
# Model saved!
#
# Epoch: 61
# train: 100%|██████████| 9/9 [00:45<00:00,  5.07s/it, dice_loss - 0.1014, iou_score - 0.8457]
# valid: 100%|██████████| 4/4 [00:06<00:00,  1.71s/it, dice_loss - 0.1143, iou_score - 0.8305]
#
# Epoch: 62
# train: 100%|██████████| 9/9 [00:43<00:00,  4.79s/it, dice_loss - 0.1027, iou_score - 0.8422]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.20s/it, dice_loss - 0.1254, iou_score - 0.818]
#
# Epoch: 63
# train: 100%|██████████| 9/9 [00:43<00:00,  4.85s/it, dice_loss - 0.09358, iou_score - 0.8577]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.02s/it, dice_loss - 0.1327, iou_score - 0.8092]
#
# Epoch: 64
# train: 100%|██████████| 9/9 [00:42<00:00,  4.73s/it, dice_loss - 0.1043, iou_score - 0.8368]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.19s/it, dice_loss - 0.1258, iou_score - 0.8183]
#
# Epoch: 65
# train: 100%|██████████| 9/9 [00:42<00:00,  4.75s/it, dice_loss - 0.09281, iou_score - 0.8562]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.06s/it, dice_loss - 0.1136, iou_score - 0.8342]
#
# Epoch: 66
# train: 100%|██████████| 9/9 [00:42<00:00,  4.76s/it, dice_loss - 0.09576, iou_score - 0.8508]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.07s/it, dice_loss - 0.1158, iou_score - 0.8325]
#
# Epoch: 67
# train: 100%|██████████| 9/9 [00:42<00:00,  4.75s/it, dice_loss - 0.09814, iou_score - 0.8459]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.90s/it, dice_loss - 0.1109, iou_score - 0.8372]
#
# Epoch: 68
# train: 100%|██████████| 9/9 [00:42<00:00,  4.73s/it, dice_loss - 0.09055, iou_score - 0.8588]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.93s/it, dice_loss - 0.1028, iou_score - 0.841]
#
# Epoch: 69
# train: 100%|██████████| 9/9 [00:42<00:00,  4.71s/it, dice_loss - 0.0969, iou_score - 0.8481]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.20s/it, dice_loss - 0.1113, iou_score - 0.8318]
#
# Epoch: 70
# train: 100%|██████████| 9/9 [00:42<00:00,  4.76s/it, dice_loss - 0.09871, iou_score - 0.8433]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.05s/it, dice_loss - 0.1082, iou_score - 0.8365]
#
# Epoch: 71
# train: 100%|██████████| 9/9 [00:42<00:00,  4.72s/it, dice_loss - 0.09513, iou_score - 0.85]
# valid: 100%|██████████| 4/4 [00:09<00:00,  2.26s/it, dice_loss - 0.108, iou_score - 0.8335]
#
# Epoch: 72
# train: 100%|██████████| 9/9 [00:42<00:00,  4.71s/it, dice_loss - 0.09889, iou_score - 0.8438]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.25s/it, dice_loss - 0.1064, iou_score - 0.8316]
#
# Epoch: 73
# train: 100%|██████████| 9/9 [00:43<00:00,  4.81s/it, dice_loss - 0.09773, iou_score - 0.8459]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.90s/it, dice_loss - 0.1151, iou_score - 0.8209]
#
# Epoch: 74
# train: 100%|██████████| 9/9 [00:42<00:00,  4.71s/it, dice_loss - 0.09463, iou_score - 0.8497]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.10s/it, dice_loss - 0.1058, iou_score - 0.8359]
#
# Epoch: 75
# train: 100%|██████████| 9/9 [00:42<00:00,  4.72s/it, dice_loss - 0.09437, iou_score - 0.8497]
# valid: 100%|██████████| 4/4 [00:07<00:00,  1.96s/it, dice_loss - 0.1035, iou_score - 0.8396]
#
# Epoch: 76
# train: 100%|██████████| 9/9 [00:43<00:00,  4.79s/it, dice_loss - 0.0919, iou_score - 0.8528]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.04s/it, dice_loss - 0.1057, iou_score - 0.8391]
#
# Epoch: 77
# train: 100%|██████████| 9/9 [00:42<00:00,  4.77s/it, dice_loss - 0.09454, iou_score - 0.848]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.19s/it, dice_loss - 0.09889, iou_score - 0.8467]
# Model saved!
#
# Epoch: 78
# train: 100%|██████████| 9/9 [00:45<00:00,  5.05s/it, dice_loss - 0.08736, iou_score - 0.862]
# valid: 100%|██████████| 4/4 [00:08<00:00,  2.20s/it, dice_loss - 0.1172, iou_score - 0.8241]
#
# Epoch: 79
# train:   0%|          | 0/9 [00:00<?, ?it/s]

# %% [markdown]
# ### Prediction on Test Data

# %%
import os # Import the 'os' module to interact with the operating system
import torch
# load best saved model checkpoint from the current run
import torch
# Define the device
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
# Assuming 'DEVICE' is defined somewhere in your code to specify the device (e.g., 'cuda' or 'cpu')

if os.path.exists(local_model_path):
    model = torch.load(local_model_path, map_location=DEVICE)
    print('Loaded saved model from ./best_model.pth')
else:
    print('Error: Could not find the saved local_model file.')
if os.path.exists(drive_model_path):
    model2 = torch.load(drive_model_path, map_location=DEVICE)
    print('Loaded saved model from ./best_model.pth')
else:
    print('Error: Could not find the saved model file.')
def compare_models(model1, model2):
    state_dict1 = model1.state_dict()
    state_dict2 = model2.state_dict()

    if state_dict1.keys() != state_dict2.keys():
        return False

    for key in state_dict1.keys():
        if not torch.equal(state_dict1[key], state_dict2[key]):
            return False

    return True

# Compare the models
if compare_models(model, model2):
    print("The model files are identical.")
else:
    print("The model files are different.")
# Out:
# Error: Could not find the saved local_model file.
# Loaded saved model from ./best_model.pth
# The model files are different.

# %%
# import os
# import torch



# if os.path.exists('./best_model.pth'):
#     model = torch.load('./best_model.pth', map_location=DEVICE)
#     print('Loaded saved model from ./best_model.pth')
# else:
#     print('Error: Could not find the saved model file.')

# %%
# load best saved model checkpoint from the current run
if os.path.exists(drive_model_path):
    best_model = torch.load(drive_model_path, map_location=DEVICE)
    print('Loaded DeepLabV3+ model from a drive.')
elif os.path.exists(local_model_path):
    best_model = torch.load(local_model_path, map_location=DEVICE)
    print('Loaded DeepLabV3+ model from this run.')

# load best saved model checkpoint from previous commit (if present)
else:
    print('Error: Could not find the saved model file.')
# Out:
# Loaded DeepLabV3+ model from a drive.

# %%
# create test dataloader (with preprocessing operation: to_tensor(...))
test_dataset = BuildingsDataset(
    x_test_dir,
    y_test_dir,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocessing_fn),
    class_rgb_values=select_class_rgb_values,
)

test_dataloader = DataLoader(test_dataset)

# test dataset for visualization (without preprocessing transformations)
test_dataset_vis = BuildingsDataset(
    x_test_dir, y_test_dir,
    augmentation=get_validation_augmentation(),
    class_rgb_values=select_class_rgb_values,
)

# get a random test image/mask index
random_idx = random.randint(0, len(test_dataset_vis)-1)
image, mask = test_dataset_vis[random_idx]

visualize(
    original_image = image,
    ground_truth_mask = colour_code_segmentation(reverse_one_hot(mask), select_class_rgb_values),
    one_hot_encoded_mask = reverse_one_hot(mask)
)

# %%
# Center crop padded image / mask to original image dims
def crop_image(image, target_image_dims=[1500,1500,3]):

    target_size = target_image_dims[0]
    image_size = len(image)
    padding = (image_size - target_size) // 2

    return image[
        padding:image_size - padding,
        padding:image_size - padding,
        :,
    ]

# %%
sample_preds_folder = '/content/drive/MyDrive/M_DATA/sample_predictions'
if not os.path.exists(sample_preds_folder):
    os.makedirs(sample_preds_folder)

# %%
for idx in range(len(test_dataset)):

    image, gt_mask = test_dataset[idx]
    image_vis = crop_image(test_dataset_vis[idx][0].astype('uint8'))
    x_tensor = torch.from_numpy(image).to(DEVICE).unsqueeze(0)
    # Predict test image
    pred_mask = best_model(x_tensor)
    pred_mask = pred_mask.detach().squeeze().cpu().numpy()
    # Convert pred_mask from `CHW` format to `HWC` format
    pred_mask = np.transpose(pred_mask,(1,2,0))
    # Get prediction channel corresponding to building
    pred_building_heatmap = pred_mask[:,:,select_classes.index('building')]
    pred_mask = crop_image(colour_code_segmentation(reverse_one_hot(pred_mask), select_class_rgb_values))
    # Convert gt_mask from `CHW` format to `HWC` format
    gt_mask = np.transpose(gt_mask,(1,2,0))
    gt_mask = crop_image(colour_code_segmentation(reverse_one_hot(gt_mask), select_class_rgb_values))
    cv2.imwrite(os.path.join(sample_preds_folder, f"sample_pred_{idx}.png"), np.hstack([image_vis, gt_mask, pred_mask])[:,:,::-1])

    visualize(
        original_image = image_vis,
        ground_truth_mask = gt_mask,
        predicted_mask = pred_mask,
        predicted_building_heatmap = pred_building_heatmap
    )
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Model Evaluation on Test Dataset

# %%
test_epoch = smp.utils.train.ValidEpoch(
    model,
    loss=loss,
    metrics=metrics,
    device=DEVICE,
    verbose=True,
)

valid_logs = test_epoch.run(test_dataloader)
print("Evaluation on Test Data: ")
print(f"Mean IoU Score: {valid_logs['iou_score']:.4f}")
print(f"Mean Dice Loss: {valid_logs['dice_loss']:.4f}")
# Out:
# valid: 100%|██████████| 10/10 [00:11<00:00,  1.17s/it, dice_loss - 0.5137, iou_score - 4.444e-14]
# Evaluation on Test Data:
# Mean IoU Score: 0.0000
# Mean Dice Loss: 0.5137

# %% [markdown]
# ### Plot Dice Loss & IoU Metric for Train vs. Val

# %%
train_logs_df = pd.DataFrame(train_logs_list)
valid_logs_df = pd.DataFrame(valid_logs_list)
train_logs_df.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3cab9b6e4e7c> in <cell line: 1>()
# ----> 1 train_logs_df = pd.DataFrame(train_logs_list)
#       2 valid_logs_df = pd.DataFrame(valid_logs_list)
#       3 train_logs_df.T
#
# NameError: name 'train_logs_list' is not defined

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.iou_score.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.iou_score.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('IoU Score', fontsize=20)
plt.title('IoU Score Plot', fontsize=20)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig('iou_score_plot.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-b894a2ed4981> in <cell line: 2>()
#       1 plt.figure(figsize=(20,8))
# ----> 2 plt.plot(train_logs_df.index.tolist(), train_logs_df.iou_score.tolist(), lw=3, label = 'Train')
#       3 plt.plot(valid_logs_df.index.tolist(), valid_logs_df.iou_score.tolist(), lw=3, label = 'Valid')
#       4 plt.xlabel('Epochs', fontsize=20)
#       5 plt.ylabel('IoU Score', fontsize=20)
#
# NameError: name 'train_logs_df' is not defined

# %%
plt.figure(figsize=(20,8))
plt.plot(train_logs_df.index.tolist(), train_logs_df.dice_loss.tolist(), lw=3, label = 'Train')
plt.plot(valid_logs_df.index.tolist(), valid_logs_df.dice_loss.tolist(), lw=3, label = 'Valid')
plt.xlabel('Epochs', fontsize=20)
plt.ylabel('Dice Loss', fontsize=20)
plt.title('Dice Loss Plot', fontsize=20)
plt.legend(loc='best', fontsize=16)
plt.grid()
plt.savefig('dice_loss_plot.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-01de62852502> in <cell line: 2>()
#       1 plt.figure(figsize=(20,8))
# ----> 2 plt.plot(train_logs_df.index.tolist(), train_logs_df.dice_loss.tolist(), lw=3, label = 'Train')
#       3 plt.plot(valid_logs_df.index.tolist(), valid_logs_df.dice_loss.tolist(), lw=3, label = 'Valid')
#       4 plt.xlabel('Epochs', fontsize=20)
#       5 plt.ylabel('Dice Loss', fontsize=20)
#
# NameError: name 'train_logs_df' is not defined
